# %%
import os
from dotenv import load_dotenv
from io import BytesIO
from elevenlabs.client import ElevenLabs

load_dotenv(verbose=True)
# Out:
# True

# %%
# ファイルロード
file_path = r"../data/raw/4人の男女の会話.mp3"
with open(file_path, "rb") as f:
    audio_data = BytesIO(f.read())

# %%
client = ElevenLabs(
  api_key=os.environ['ELEVENLABS_API_KEY'],
)

# %%
transcription = client.speech_to_text.convert(
    file=audio_data,
    model_id="scribe_v1",  # モデルの指定。現時点では "scribe_v1" のみサポート
    tag_audio_events=True, # 笑いや拍手などの音声イベントのタグ付けを有効化
    language_code="jpn",   # 音声の言語。指定がない場合は自動判別
    diarize=True,          # 話者ダイアライぜーションのアノテーションを有効化
)

# %%
def format_time(t):
    """
    秒数 t を "mm:ss.mmm" 形式の文字列に変換する
    """
    minutes = int(t // 60)
    seconds = t - minutes * 60
    return f"{minutes:02d}:{seconds:06.3f}"

# セグメント毎にまとめるためのリスト
segments = []
current_segment = None
gap_threshold = 0.5  # 次の単語との間隔がこの秒数以上ならセグメントを分割

for w in transcription.words:
    # 各単語の情報（辞書形式を想定）
    w = dict(w)
    speaker = w.get("speaker_id", "unknown")
    start = w.get("start", 0)
    end = w.get("end", 0)
    text_piece = w.get("text", "")
    
    # current_segment が未定義の場合は新規作成
    if current_segment is None:
        current_segment = {"speaker": speaker, "start": start, "end": end, "text": text_piece}
    else:
        # 話者が変わるか、または前の単語とのギャップが大きい場合はセグメントを終了する
        if speaker != current_segment["speaker"] or (start - current_segment["end"]) > gap_threshold:
            segments.append(current_segment)
            current_segment = {"speaker": speaker, "start": start, "end": end, "text": text_piece}
        else:
            # 同一セグメントに追加：end 時刻を更新し、テキストを連結
            current_segment["end"] = end
            current_segment["text"] += text_piece

# ループ後、残ったセグメントを追加
if current_segment is not None:
    segments.append(current_segment)

# 各セグメントを指定のフォーマットで出力する
for seg in segments:
    start_str = format_time(seg["start"])
    end_str = format_time(seg["end"])
    # speaker_id が "speaker_0" の場合は SPEAKER_00 のように整形
    spk = seg["speaker"]
    if spk.startswith("speaker_"):
        number = spk.split("_")[1]
        spk_label = f"SPEAKER_{int(number):02d}"
    else:
        spk_label = spk.upper()
    print(f"[{start_str} - {end_str}] {spk_label}: {seg['text']}")
# Out:
# [00:00.280 - 00:04.619] SPEAKER_00: こんにちは！シェアハウスコルサってここですか？
# [00:04.619 - 00:07.399] SPEAKER_01: もしかして、四人目の住人の人？
# [00:07.399 - 00:15.059] SPEAKER_00: はい、吉田有理です。よろしくお願いします。思ったよりいいとこですね、ここ。
# [00:15.059 - 00:19.119] SPEAKER_01: そうでしょ？僕チョウです。
# [00:19.119 - 00:24.239] SPEAKER_02: やっと来た。ユリ今何時だと思ってる？
# [00:24.239 - 00:28.579] SPEAKER_00: ごめんごめん、スティーブつい二度寝しちゃって。
# [00:28.579 - 00:30.219] SPEAKER_02: せめて電話ぐらい。
# [00:30.219 - 00:33.799] SPEAKER_00: はい。本当にごめんなさい。
# [00:33.799 - 00:39.059] SPEAKER_01: 二度寝気持ちいいんですよね。僕もよくやっちゃう。
# [00:39.059 - 00:46.000] SPEAKER_03: 共有スペースはもう片付いたから、そこにある吉田さんの荷物を自分の部屋に運んでくれる？
# [00:46.000 - 00:48.259] SPEAKER_00: あ、ユリでいいです。
# [00:48.259 - 00:52.020] SPEAKER_03: じゃあユリさん、お願いね。私はアナ。
# [00:52.020 - 00:56.939] SPEAKER_00: アナさん、よろしくお願いします。

# %%
print(transcription.text)
# Out:
# こんにちは！シェアハウスコルサってここですか？ もしかして、四人目の住人の人？ はい、吉田有理です。よろしくお願いします。思ったよりいいとこですね、ここ。 そうでしょ？僕チョウです。 やっと来た。ユリ今何時だと思ってる？ ごめんごめん、スティーブつい二度寝しちゃって。 せめて電話ぐらい。 はい。本当にごめんなさい。 二度寝気持ちいいんですよね。僕もよくやっちゃう。 共有スペースはもう片付いたから、そこにある吉田さんの荷物を自分の部屋に運んでくれる？ あ、ユリでいいです。 じゃあユリさん、お願いね。私はアナ。 アナさん、よろしくお願いします。

# %%
for w in transcription.words:
    print(w.model_dump())
# Out:
# {'text': 'こ', 'start': 0.28, 'end': 0.359, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ん', 'start': 0.359, 'end': 0.459, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'に', 'start': 0.459, 'end': 0.579, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ち', 'start': 0.579, 'end': 0.719, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'は', 'start': 0.719, 'end': 0.879, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '！', 'start': 0.879, 'end': 1.599, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'シ', 'start': 1.599, 'end': 1.659, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ェ', 'start': 1.659, 'end': 1.759, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ア', 'start': 1.759, 'end': 1.899, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ハ', 'start': 1.899, 'end': 2.0, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ウ', 'start': 2.0, 'end': 2.159, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ス', 'start': 2.159, 'end': 2.359, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'コ', 'start': 2.359, 'end': 2.46, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ル', 'start': 2.46, 'end': 2.619, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'サ', 'start': 2.619, 'end': 2.799, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'っ', 'start': 2.799, 'end': 2.879, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'て', 'start': 2.879, 'end': 3.079, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'こ', 'start': 3.079, 'end': 3.179, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'こ', 'start': 3.179, 'end': 3.299, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'で', 'start': 3.299, 'end': 3.399, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'す', 'start': 3.399, 'end': 3.5, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'か', 'start': 3.5, 'end': 3.699, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '？', 'start': 3.699, 'end': 4.639, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': ' ', 'start': 4.639, 'end': 4.619, 'type': 'spacing', 'speaker_id': 'speaker_0', 'characters': [{'text': ' ', 'start': 4.639, 'end': 4.619}]}
# {'text': 'も', 'start': 4.619, 'end': 4.739, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'し', 'start': 4.739, 'end': 4.859, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'か', 'start': 4.859, 'end': 4.94, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'し', 'start': 4.94, 'end': 5.039, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'て', 'start': 5.039, 'end': 5.559, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '、', 'start': 5.559, 'end': 5.619, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '四', 'start': 5.619, 'end': 5.98, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '人', 'start': 5.98, 'end': 6.0, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '目', 'start': 6.0, 'end': 6.119, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'の', 'start': 6.119, 'end': 6.279, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '住', 'start': 6.279, 'end': 6.44, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '人', 'start': 6.44, 'end': 6.559, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'の', 'start': 6.559, 'end': 6.659, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '人', 'start': 6.659, 'end': 6.879, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '？', 'start': 6.879, 'end': 7.419, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': ' ', 'start': 7.419, 'end': 7.399, 'type': 'spacing', 'speaker_id': 'speaker_1', 'characters': [{'text': ' ', 'start': 7.419, 'end': 7.399}]}
# {'text': 'は', 'start': 7.399, 'end': 7.5, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'い', 'start': 7.5, 'end': 7.619, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '、', 'start': 7.619, 'end': 8.3, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '吉', 'start': 8.3, 'end': 8.699, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '田', 'start': 8.699, 'end': 8.699, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '有', 'start': 8.699, 'end': 8.819, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '理', 'start': 8.819, 'end': 8.939, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'で', 'start': 8.939, 'end': 9.079, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'す', 'start': 9.079, 'end': 9.739, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '。', 'start': 9.739, 'end': 9.76, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'よ', 'start': 9.76, 'end': 9.859, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ろ', 'start': 9.859, 'end': 9.96, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'し', 'start': 9.96, 'end': 10.059, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'く', 'start': 10.059, 'end': 10.139, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'お', 'start': 10.139, 'end': 10.219, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '願', 'start': 10.219, 'end': 10.439, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'い', 'start': 10.439, 'end': 10.519, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'し', 'start': 10.519, 'end': 10.659, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ま', 'start': 10.659, 'end': 10.779, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'す', 'start': 10.779, 'end': 10.88, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '。', 'start': 10.88, 'end': 11.979, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '思', 'start': 11.979, 'end': 12.219, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'っ', 'start': 12.219, 'end': 12.359, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'た', 'start': 12.359, 'end': 12.439, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'よ', 'start': 12.439, 'end': 12.579, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'り', 'start': 12.579, 'end': 13.059, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'い', 'start': 13.059, 'end': 13.119, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'い', 'start': 13.119, 'end': 13.259, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'と', 'start': 13.259, 'end': 13.359, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'こ', 'start': 13.359, 'end': 13.439, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'で', 'start': 13.439, 'end': 13.599, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'す', 'start': 13.599, 'end': 13.659, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ね', 'start': 13.659, 'end': 13.96, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '、', 'start': 13.96, 'end': 14.019, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'こ', 'start': 14.019, 'end': 14.159, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'こ', 'start': 14.159, 'end': 14.259, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '。', 'start': 14.259, 'end': 15.079, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': ' ', 'start': 15.079, 'end': 15.059, 'type': 'spacing', 'speaker_id': 'speaker_0', 'characters': [{'text': ' ', 'start': 15.079, 'end': 15.059}]}
# {'text': 'そ', 'start': 15.059, 'end': 15.199, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'う', 'start': 15.199, 'end': 15.319, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'で', 'start': 15.319, 'end': 15.439, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'し', 'start': 15.439, 'end': 15.5, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'ょ', 'start': 15.5, 'end': 15.719, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '？', 'start': 15.719, 'end': 16.6, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '僕', 'start': 16.6, 'end': 17.159, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'チ', 'start': 17.159, 'end': 17.239, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'ョ', 'start': 17.239, 'end': 17.279, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'ウ', 'start': 17.279, 'end': 17.379, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'で', 'start': 17.379, 'end': 17.52, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'す', 'start': 17.52, 'end': 17.659, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '。', 'start': 17.659, 'end': 19.139, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': ' ', 'start': 19.139, 'end': 19.119, 'type': 'spacing', 'speaker_id': 'speaker_1', 'characters': [{'text': ' ', 'start': 19.139, 'end': 19.119}]}
# {'text': 'や', 'start': 19.119, 'end': 19.239, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'っ', 'start': 19.239, 'end': 19.459, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'と', 'start': 19.459, 'end': 19.579, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': '来', 'start': 19.579, 'end': 19.779, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'た', 'start': 19.779, 'end': 20.079, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': '。', 'start': 20.079, 'end': 20.92, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'ユ', 'start': 20.92, 'end': 21.1, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'リ', 'start': 21.1, 'end': 22.039, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': '今', 'start': 22.039, 'end': 22.279, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': '何', 'start': 22.279, 'end': 22.479, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': '時', 'start': 22.479, 'end': 22.6, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'だ', 'start': 22.6, 'end': 22.699, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'と', 'start': 22.699, 'end': 22.819, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': '思', 'start': 22.819, 'end': 23.0, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'っ', 'start': 23.0, 'end': 23.039, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'て', 'start': 23.039, 'end': 23.119, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'る', 'start': 23.119, 'end': 23.34, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': '？', 'start': 23.34, 'end': 24.26, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': ' ', 'start': 24.26, 'end': 24.239, 'type': 'spacing', 'speaker_id': 'speaker_2', 'characters': [{'text': ' ', 'start': 24.26, 'end': 24.239}]}
# {'text': 'ご', 'start': 24.239, 'end': 24.439, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'め', 'start': 24.439, 'end': 24.579, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ん', 'start': 24.579, 'end': 24.699, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ご', 'start': 24.699, 'end': 24.84, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'め', 'start': 24.84, 'end': 25.019, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ん', 'start': 25.019, 'end': 25.26, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '、', 'start': 25.26, 'end': 25.26, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ス', 'start': 25.26, 'end': 25.359, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'テ', 'start': 25.359, 'end': 25.42, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ィ', 'start': 25.42, 'end': 25.519, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ー', 'start': 25.519, 'end': 25.559, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ブ', 'start': 25.559, 'end': 26.619, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'つ', 'start': 26.619, 'end': 26.819, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'い', 'start': 26.819, 'end': 26.979, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '二', 'start': 26.979, 'end': 27.079, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '度', 'start': 27.079, 'end': 27.299, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '寝', 'start': 27.299, 'end': 27.359, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'し', 'start': 27.359, 'end': 27.459, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ち', 'start': 27.459, 'end': 27.479, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ゃ', 'start': 27.479, 'end': 27.559, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'っ', 'start': 27.559, 'end': 27.68, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'て', 'start': 27.68, 'end': 27.819, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '。', 'start': 27.819, 'end': 28.6, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': ' ', 'start': 28.6, 'end': 28.579, 'type': 'spacing', 'speaker_id': 'speaker_0', 'characters': [{'text': ' ', 'start': 28.6, 'end': 28.579}]}
# {'text': 'せ', 'start': 28.579, 'end': 28.739, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'め', 'start': 28.739, 'end': 28.879, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'て', 'start': 28.879, 'end': 29.119, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': '電', 'start': 29.119, 'end': 29.279, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': '話', 'start': 29.279, 'end': 29.399, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'ぐ', 'start': 29.399, 'end': 29.519, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'ら', 'start': 29.519, 'end': 29.639, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': 'い', 'start': 29.639, 'end': 29.819, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': '。', 'start': 29.819, 'end': 30.239, 'type': 'word', 'speaker_id': 'speaker_2', 'characters': None}
# {'text': ' ', 'start': 30.239, 'end': 30.219, 'type': 'spacing', 'speaker_id': 'speaker_2', 'characters': [{'text': ' ', 'start': 30.239, 'end': 30.219}]}
# {'text': 'は', 'start': 30.219, 'end': 30.379, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'い', 'start': 30.379, 'end': 30.519, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '。', 'start': 30.519, 'end': 31.299, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '本', 'start': 31.299, 'end': 31.459, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '当', 'start': 31.459, 'end': 31.599, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'に', 'start': 31.599, 'end': 31.76, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ご', 'start': 31.76, 'end': 31.899, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'め', 'start': 31.899, 'end': 32.0, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ん', 'start': 32.0, 'end': 32.139, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'な', 'start': 32.139, 'end': 32.319, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'さ', 'start': 32.319, 'end': 32.439, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'い', 'start': 32.439, 'end': 32.579, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '。', 'start': 32.579, 'end': 33.819, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': ' ', 'start': 33.819, 'end': 33.799, 'type': 'spacing', 'speaker_id': 'speaker_0', 'characters': [{'text': ' ', 'start': 33.819, 'end': 33.799}]}
# {'text': '二', 'start': 33.799, 'end': 33.88, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '度', 'start': 33.88, 'end': 34.059, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '寝', 'start': 34.059, 'end': 34.5, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '気', 'start': 34.5, 'end': 34.579, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '持', 'start': 34.579, 'end': 34.739, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'ち', 'start': 34.739, 'end': 34.84, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'い', 'start': 34.84, 'end': 34.919, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'い', 'start': 34.919, 'end': 34.959, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'ん', 'start': 34.959, 'end': 35.059, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'で', 'start': 35.059, 'end': 35.099, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'す', 'start': 35.099, 'end': 35.2, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'よ', 'start': 35.2, 'end': 35.399, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'ね', 'start': 35.399, 'end': 35.659, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '。', 'start': 35.659, 'end': 36.619, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '僕', 'start': 36.619, 'end': 36.88, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'も', 'start': 36.88, 'end': 37.04, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'よ', 'start': 37.04, 'end': 37.18, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'く', 'start': 37.18, 'end': 37.299, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'や', 'start': 37.299, 'end': 37.399, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'っ', 'start': 37.399, 'end': 37.559, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'ち', 'start': 37.559, 'end': 37.619, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'ゃ', 'start': 37.619, 'end': 37.7, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': 'う', 'start': 37.7, 'end': 37.799, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': '。', 'start': 37.799, 'end': 39.079, 'type': 'word', 'speaker_id': 'speaker_1', 'characters': None}
# {'text': ' ', 'start': 39.079, 'end': 39.059, 'type': 'spacing', 'speaker_id': 'speaker_1', 'characters': [{'text': ' ', 'start': 39.079, 'end': 39.059}]}
# {'text': '共', 'start': 39.059, 'end': 39.259, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '有', 'start': 39.259, 'end': 39.439, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ス', 'start': 39.439, 'end': 39.559, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ペ', 'start': 39.559, 'end': 39.619, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ー', 'start': 39.619, 'end': 39.719, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ス', 'start': 39.719, 'end': 39.84, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'は', 'start': 39.84, 'end': 40.0, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'も', 'start': 40.0, 'end': 40.2, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'う', 'start': 40.2, 'end': 40.2, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '片', 'start': 40.2, 'end': 40.439, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '付', 'start': 40.439, 'end': 40.52, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'い', 'start': 40.52, 'end': 40.639, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'た', 'start': 40.639, 'end': 40.739, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'か', 'start': 40.739, 'end': 40.899, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ら', 'start': 40.899, 'end': 40.959, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '、', 'start': 40.959, 'end': 41.939, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'そ', 'start': 41.939, 'end': 42.079, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'こ', 'start': 42.079, 'end': 42.2, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'に', 'start': 42.2, 'end': 42.319, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'あ', 'start': 42.319, 'end': 42.419, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'る', 'start': 42.419, 'end': 42.579, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '吉', 'start': 42.579, 'end': 42.799, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '田', 'start': 42.799, 'end': 42.939, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'さ', 'start': 42.939, 'end': 43.0, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ん', 'start': 43.0, 'end': 43.099, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'の', 'start': 43.099, 'end': 43.2, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '荷', 'start': 43.2, 'end': 43.299, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '物', 'start': 43.299, 'end': 43.52, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'を', 'start': 43.52, 'end': 44.159, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '自', 'start': 44.159, 'end': 44.279, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '分', 'start': 44.279, 'end': 44.419, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'の', 'start': 44.419, 'end': 44.539, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '部', 'start': 44.539, 'end': 44.639, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '屋', 'start': 44.639, 'end': 44.84, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'に', 'start': 44.84, 'end': 44.84, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '運', 'start': 44.84, 'end': 45.079, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ん', 'start': 45.079, 'end': 45.119, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'で', 'start': 45.119, 'end': 45.2, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'く', 'start': 45.2, 'end': 45.299, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'れ', 'start': 45.299, 'end': 45.379, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'る', 'start': 45.379, 'end': 45.52, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '？', 'start': 45.52, 'end': 46.02, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': ' ', 'start': 46.02, 'end': 46.0, 'type': 'spacing', 'speaker_id': 'speaker_3', 'characters': [{'text': ' ', 'start': 46.02, 'end': 46.0}]}
# {'text': 'あ', 'start': 46.0, 'end': 46.119, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '、', 'start': 46.119, 'end': 46.84, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ユ', 'start': 46.84, 'end': 46.959, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'リ', 'start': 46.959, 'end': 47.099, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'で', 'start': 47.099, 'end': 47.18, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'い', 'start': 47.18, 'end': 47.259, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'い', 'start': 47.259, 'end': 47.419, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'で', 'start': 47.419, 'end': 47.419, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'す', 'start': 47.419, 'end': 47.579, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '。', 'start': 47.579, 'end': 48.279, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': ' ', 'start': 48.279, 'end': 48.259, 'type': 'spacing', 'speaker_id': 'speaker_0', 'characters': [{'text': ' ', 'start': 48.279, 'end': 48.259}]}
# {'text': 'じ', 'start': 48.259, 'end': 48.279, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ゃ', 'start': 48.279, 'end': 48.419, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'あ', 'start': 48.419, 'end': 48.599, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ユ', 'start': 48.599, 'end': 48.719, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'リ', 'start': 48.719, 'end': 48.899, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'さ', 'start': 48.899, 'end': 49.059, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ん', 'start': 49.059, 'end': 49.239, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '、', 'start': 49.239, 'end': 49.259, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'お', 'start': 49.259, 'end': 49.36, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '願', 'start': 49.36, 'end': 49.579, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'い', 'start': 49.579, 'end': 49.619, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ね', 'start': 49.619, 'end': 49.759, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '。', 'start': 49.759, 'end': 50.639, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '私', 'start': 50.639, 'end': 50.959, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'は', 'start': 50.959, 'end': 51.059, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ア', 'start': 51.059, 'end': 51.18, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': 'ナ', 'start': 51.18, 'end': 51.279, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': '。', 'start': 51.279, 'end': 52.039, 'type': 'word', 'speaker_id': 'speaker_3', 'characters': None}
# {'text': ' ', 'start': 52.039, 'end': 52.02, 'type': 'spacing', 'speaker_id': 'speaker_3', 'characters': [{'text': ' ', 'start': 52.039, 'end': 52.02}]}
# {'text': 'ア', 'start': 52.02, 'end': 52.119, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ナ', 'start': 52.119, 'end': 52.299, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'さ', 'start': 52.299, 'end': 52.379, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ん', 'start': 52.379, 'end': 53.0, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '、', 'start': 53.0, 'end': 53.039, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'よ', 'start': 53.039, 'end': 53.119, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ろ', 'start': 53.119, 'end': 53.219, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'し', 'start': 53.219, 'end': 53.299, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'く', 'start': 53.299, 'end': 53.379, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'お', 'start': 53.379, 'end': 53.479, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '願', 'start': 53.479, 'end': 53.619, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'い', 'start': 53.619, 'end': 53.759, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'し', 'start': 53.759, 'end': 53.86, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'ま', 'start': 53.86, 'end': 54.0, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': 'す', 'start': 54.0, 'end': 54.099, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
# {'text': '。', 'start': 54.099, 'end': 56.939, 'type': 'word', 'speaker_id': 'speaker_0', 'characters': None}
